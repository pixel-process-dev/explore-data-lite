# %% [markdown]
# # Data Visualization Building Blocks

# %% [markdown]
# ## Figures, axes, and layout components for matplotlib and seaborn

# %%
# Import required packages into environment
# %pip install -q seaborn pandas matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load built-in tips dataset
tips = pd.read_csv('data/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
agg = tips.groupby("day", as_index=False)["total_bill"].mean()

# %% [markdown]
# ### Matplotlib

# %%
plt.bar(tips['day'], tips['total_bill'])
plt.title("Total Bill by Day")
plt.xlabel("Day")
plt.ylabel("Total Bill ($)")
plt.tight_layout()
# plt.savefig("images/matplotlib.png")
plt.show()

# %% [markdown]
# ### Seaborn

# %%
fig, ax = plt.subplots()
sns.barplot(data=tips, x="day", y="total_bill", ax=ax)
ax.set_title("Average Bill by Day", fontsize=14)
ax.set_xlabel("Day", fontsize=12)
ax.set_ylabel("Total Bill", fontsize=12)
plt.tight_layout()
# plt.savefig("images/seaborn_chart.png")
plt.show()
